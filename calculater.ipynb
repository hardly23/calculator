# %%
from tkinter import *
from math import tan  
from math import cos 
from math import sin
from math import isqrt
from math import factorial
from math import pi
from math import cosh
from math import sinh
from math import tanh
from math import log
from math import log10

me=Tk()
me.geometry("654x560")
me.title("CALCULATOR")

me.config(cursor="arrow")
melabel = Label(me,text="CALCULATOR",bg="purple3",font=("Times",30))
melabel.pack(side=TOP)
me.config(background="grey3")

textin=StringVar()
operator=""

def clickbut(number):
    global operator
    operator=operator+str(number)
    textin.set(operator)  

def clebut():
    global operator
    operator= ""
    textin.set('')
    
    
def equlbut():
    global operator
    add = str(eval(operator))
    textin.set(add)
    operator = ''
    
def donothing():
    filewin = Toplevel(me)
    
#     button = Button(filewin, text="Do nothing button")
    button.pack()

menubar = Menu(me,bg="black")
filemenu = Menu(menubar,fg="white",bg='grey1',font=("Times",30))
filemenu.add_command(label="New", command=donothing)
filemenu.add_command(label="Open", command=donothing)
filemenu.add_command(label="Save", command=donothing)
filemenu.add_command(label="Save as...", command=donothing)
filemenu.add_command(label="Close", command=donothing)
filemenu.add_command(label="Exit", command=me.quit)
menubar.add_cascade(label="File", menu=filemenu)

metext=Entry(me,font=("Courier New",15,'bold'),textvar=textin,width=25,bd=5,fg="white",bg='grey')
metext.pack()


butClear=Button(me,padx=14,pady=55,bd=4,bg='light salmon',text="CE",command=clebut,font=("Courier New",11,'bold'))
butClear.place(x=413,y=310)


but1=Button(me,padx=28,pady=14,bd=4,bg='yellow green',command=lambda:clickbut(1),text="1",font=("Courier New",16,'bold'))
but1.place(x=10,y=100)

but2=Button(me,padx=28,pady=14,bd=4,bg='turquoise4',command=lambda:clickbut(2),text="2",font=("Courier New",16,'bold'))
but2.place(x=10,y=170)

but3=Button(me,padx=28,pady=14,bd=4,bg='SteelBlue1',command=lambda:clickbut(3),text="3",font=("Courier New",16,'bold'))
but3.place(x=10,y=240)

but4=Button(me,padx=28,pady=14,bd=4,bg='lawn green',command=lambda:clickbut(4),text="4",font=("Courier New",16,'bold'))
but4.place(x=100,y=100)

but5=Button(me,padx=28,pady=14,bd=4,bg='turquoise3',command=lambda :clickbut(5),text="5",font=("Courier New",16,'bold'))
but5.place(x=100,y=170)

but6=Button(me,padx=28,pady=14,bd=4,bg='SteelBlue2',command=lambda:clickbut(6),text="6",font=("Courier New",16,'bold'))
but6.place(x=100,y=240)

but7=Button(me,padx=28,pady=14,bd=4,bg='lime green',command=lambda:clickbut(7),text="7",font=("Courier New",16,'bold'))
but7.place(x=190,y=100)

but8=Button(me,padx=28,pady=14,bd=4,bg='turquoise2',command=lambda:clickbut(8),text="8",font=("Courier New",16,'bold'))
but8.place(x=190,y=170)

but9=Button(me,padx=28,pady=14,bd=4,bg='SteelBlue3',command=lambda:clickbut(9),text="9",font=("Courier New",16,'bold'))
but9.place(x=190,y=240)

but0=Button(me,padx=28,pady=14,bd=4,bg='green1',command=lambda:clickbut(0),text="0",font=("Courier New",16,'bold'))
but0.place(x=10,y=310)

butdot=Button(me,padx=47,pady=14,bd=4,bg='green2',command=lambda:clickbut(")"),text=")",font=("Courier New",16,'bold'))
butdot.place(x=100,y=310)

buttan=Button(me,padx=14,pady=20,bd=4,bg='green yellow',text="tan",command=lambda:clickbut("tan("),font=("Courier New",9,'bold'))
buttan.place(x=413,y=100)

buttan1=Button(me,padx=14,pady=20,bd=4,bg='green yellow',text="tanh",command=lambda:clickbut("tanh("),font=("Courier New",9,'bold'))
buttan1.place(x=345,y=310)

butSub=Button(me,padx=14,pady=20,bd=4,bg='turquoise1',text="cos",command=lambda :clickbut("cos("),font=("Courier New",9,'bold'))
butSub.place(x=413,y=170)

butSub1=Button(me,padx=14,pady=20,bd=4,bg='turquoise1',text="cosh",command=lambda :clickbut("cosh("),font=("Courier New",9,'bold'))
butSub1.place(x=345,y=170)

butMl=Button(me,padx=14,pady=20,bd=4,bg='SteelBlue4',text="sin",command=lambda :clickbut("sin("),font=("Courier New",9,'bold'))
butMl.place(x=413,y=240)

butMl1=Button(me,padx=14,pady=20,bd=4,bg='SteelBlue4',text="sinh",command=lambda :clickbut("sinh("),font=("Courier New",9,'bold'))
butMl1.place(x=345,y=240)

butDiv=Button(me,padx=8,pady=15,bd=4,bg='green3',text=" √ ",command=lambda:clickbut("isqrt("),font=("Courier New",14,'bold'))
butDiv.place(x=280,y=380)


butDiv=Button(me,padx=8,pady=15,bd=4,bg='green3',text=" ! ",command=lambda:clickbut("factorial("),font=("Courier New",14,'bold'))
butDiv.place(x=345,y=100)

butPi=Button(me,padx=8,pady=15,bd=4,bg='green3',text=" π ",command=lambda:clickbut("pi"),font=("Courier New",14,'bold'))
butPi.place(x=346,y=380)


butSu=Button(me,padx=18,pady=15,bd=4,bg='turquoise1',text="+",command=lambda :clickbut("+"),font=("Courier New",14,'bold'))
butSu.place(x=280,y=100)

butML=Button(me,padx=18,pady=15,bd=4,bg='turquoise1',text="*",command=lambda :clickbut("*"),font=("Courier New",14,'bold'))
butML.place(x=280,y=170)

butDIV=Button(me,padx=18,pady=15,bd=4,bg='turquoise1',text="/",command=lambda :clickbut("/"),font=("Courier New",14,'bold'))
butDIV.place(x=280,y=240)

butMIN=Button(me,padx=18,pady=15,bd=4,bg='turquoise1',text="-",command=lambda :clickbut("-"),font=("Courier New",14,'bold'))
butMIN.place(x=280,y=310)



butDot=Button(me,padx=8,pady=20,bd=4,bg='green3',text=" . ",command=lambda:clickbut("."),font=("Courier New",10,'bold'))
butDot.place(x=228,y=310)



butequal=Button(me,padx=118,pady=14,bd=4,bg='cyan3',text="=",command=equlbut,font=("Courier New",16,'bold'))
butequal.place(x=10,y=380)

me.config(menu=menubar)
me.mainloop()
